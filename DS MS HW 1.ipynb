# %% [markdown]
# <a href="https://colab.research.google.com/github/yustinaivanova/math_netology/blob/master/dz_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Математики для data science.
# # Домашнее задание 1.

# %% [markdown]
# **Задание на отображение множеств.**

# %% [markdown]
# **Задание 1.**

# %% [markdown]
# Написать функцию отображения элементов одного множества в другое. Первое множество - художники, второе множество - картины художников.
# Множество художников - Серов, Левитан, Репин, Васнецов, Шишкин.
# Множество картин - "Утро в сосновом бору", "Богатыри", "Золотая осень", "Девочка с персиками", "Запорожцы", "Буралки на Волге", "Март", "Алёнушка".

# %% [markdown]
# # Решение

# %%
artists = ['Серов', 'Левитан', 'Репин', 'Васнецов', 'Шишкин']

paintings = ['Девочка с персиками', 'Запорожцы', 'Бурлаки на Волге',
             'Март', 'Алёнушка', "Утро в сосновом бору", "Богатыри", "Золотая осень"]

our_dict = dict()
our_dict['Серов'] = paintings[0]
our_dict['Репин'] = paintings[1] + ', ' + paintings[2]
our_dict['Левитан'] = paintings[3] + ', ' + paintings[7]
our_dict['Васнецов'] = paintings[4] + ', ' + paintings[6]
our_dict['Шишкин'] = paintings[5]

# %%
for key, value in our_dict.items():
    print('{}: {}'.format(key, value))
# Out:
# Серов: Девочка с персиками
# Репин: Запорожцы, Бурлаки на Волге
# Левитан: Март, Золотая осень
# Васнецов: Алёнушка, Богатыри
# Шишкин: Утро в сосновом бору

# %% [markdown]
# **Полиномиальные функции.**

# %% [markdown]
# **Задание 2**. Найти из следующих функций те, которые являются полиномиальной функцией.

# %% [markdown]
# *  $$f(x)=\frac{1}{2}x^{6}-1\frac{5}{6}x+\frac{1}{3}$$
# *  $$f(x)=\frac{3x^{6}-11x+2}{6}$$
# *  $$f(x)=\frac{3x^{6}-11x+2}{6x}$$
# *  $$f(x)=x^{5}-3x^{2}+7x^{-2}$$
# *  $$f(x)=(5x^{2}-2)^3-\frac{1}{2}x^{3}$$
# *  $$f(x)=(1+\sqrt{x})^{3}-5(1+\sqrt{x})$$
# *  $$f(x)=\pi $$

# %% [markdown]
# # Решение
# - полином
# - полином
# - не полином, т.к. имеется степень -1
# - не полином, т.к. имеется степень -2
# - полином
# - не полином, так как имеет дробные степени
# - полином

# %% [markdown]
# **Задание 3**. Раскрыть скобки для следующего полинома $$(2x+1)^{2}(x-1)-x(4x^{2}-1)-x(4x^{2}-1)=ax^3+bx^2+cx+d$$ найти коэффициенты для a, b, c, d.

# %% [markdown]
# # Решение
# **Получаем, что $$a=-4, b=0, c=-1, d=-1$$**
# **И сам полином: $$-4x^{3}-x-1$$**

# %% [markdown]
# Для данного задания полезно использовать следующие формулы сокращенного умножения:
# ![alt text](https://sun9-38.userapi.com/c851232/v851232044/19c5b0/7Yy6qz-MUHA.jpg)

# %% [markdown]
# Чему равна степень полинома?

# %% [markdown]
# ### Степень полинома равна 3

# %% [markdown]
# Нарисовать график для полинома.

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

def func(x):
    return -4 * x**3 - x - 1
  
x1 = np.linspace(-3.0, 3.0, 100)
# на основе вектора x строим значения для вектора y
y1 = [func(x1[i]) for i in range(len(x1))]

plt.plot(x1, y1)
plt.title('График функции')
plt.ylabel('y')
plt.xlabel('x')
plt.ylim(-3, 3)
plt.show()

# %% [markdown]
# **Задание 3**.
# Для заданных функций найти подходящий график (не все функции имеют график):
# $\frac{3}{4}x-1$,  $\frac{3}{4}x+2$, $2-2x$, $2+2x$, $\frac{1}{4}(x+1)^{2}-2 $, $\frac{1}{4}(x-1)^2-2$, $(x-1)(x-3)$, $(x+1)(x+3)$, $2-x^2$, $2-\frac{1}{4}x^2$

# %%
x = np.linspace(-3.0, 3.0, 100)
y = lambda x: 3/4 * x - 1
plt.grid()

plt.plot(x, y(x))

# %% [markdown]
# ### 1. Таким образом, это второй график во втором ряду.

# %%
x = np.linspace(-3.0, 3.0, 100)
y = lambda x: 3/4 * x + 2
plt.grid()

plt.plot(x, y(x))

# %% [markdown]
# ### 2. Таким образом, такой график отсутствует.

# %%
x = np.linspace(-3.0, 3.0, 100)
y = lambda x: 2 - 2 * x
plt.grid()

plt.plot(x, y(x))

# %% [markdown]
# ### 3. Таким образом, это первый график в первом ряду.

# %%
x = np.linspace(-3.0, 3.0, 100)
y = lambda x: 2 + 2 * x
plt.grid()

plt.plot(x, y(x))

# %% [markdown]
# ### 4. Таким образом, такой график отсутствует.

# %%
x = np.linspace(-3.0, 3.0, 100)
y = lambda x: 1/4 * (x + 1)**2 - 2
plt.grid()

plt.plot(x, y(x))

# %% [markdown]
# ### 5. Таким образом, это первый график во втором ряду.

# %%
x = np.linspace(-3.0, 3, 100)
y = lambda x: 1/4 * (x - 1)**2 - 2
plt.grid()

plt.plot(x, y(x))

# %% [markdown]
# ### 6. Таким образом, такой график отсутствует.

# %%
x = np.linspace(-3.0, 3, 100)
y = lambda x: (x - 1)*(x - 3)
plt.grid()

plt.plot(x, y(x))

# %% [markdown]
# ### 7. Таким образом, это третий график во втором ряду.

# %%
x = np.linspace(-3.0, 3, 100)
y = lambda x: (x + 1)*(x + 3)
plt.grid()

plt.plot(x, y(x))

# %% [markdown]
# ### 8. Таким образом, такой график отсутствует.

# %%
x = np.linspace(-3.0, 3, 100)
y = lambda x: 2 - x**2
plt.grid()

plt.plot(x, y(x))

# %% [markdown]
# ### 9. Таким образом, это третий график в первом ряду.

# %%
x = np.linspace(-3.0, 3, 100)
y = lambda x: 2 - 1/4 * x**2
plt.grid()

plt.plot(x, y(x))

# %% [markdown]
# ### 10. Таким образом, это второй график в первом ряду.

# %% [markdown]
# ![alt text](https://pp.userapi.com/c855532/v855532908/aadd4/uWjIZGDfw0s.jpg)

# %% [markdown]
# **Задание 4.** Найти минимальную степень следующего полинома:
#
# ![alt text](https://pp.userapi.com/c855532/v855532908/aadcd/PZdPYTQT02A.jpg)

# %% [markdown]
# ### Минимальная степень - 5, т.к. пять пересечений с осью х

# %% [markdown]
# **Задания повышенного уровня**

# %% [markdown]
# Почему следующие функции не являются полиномиальными?
# $$y=5x^{-2}+1$$
# $$y=3x^{1/2}+2$$
# $$y=(5x+1)/(3x)$$

# %% [markdown]
# ### В первом и третье случае, так как имеется отрицательная степень, во втором, так как степень дробная.

# %% [markdown]
# Найдите наибольшее и наименьшее значение функции $y = x^3 + 2x^2 + x + 3 $ на отрезке [-4;-1].

# %%
x = np.linspace(-4.0, -1.0, 100)
y = lambda x: x**3 + 2*x**2 + x + 3

plt.plot(x, y(x))

# %%
y(x)
# Out:
# array([-33.        , -32.00915491, -31.03650833, -30.08189331,
#        -29.14514289, -28.2260901 , -27.32456799, -26.44040961,
#        -25.57344798, -24.72351615, -23.89044717, -23.07407407,
#        -22.2742299 , -21.4907477 , -20.7234605 , -19.97220135,
#        -19.23680329, -18.51709937, -17.81292261, -17.12410607,
#        -16.45048279, -15.7918858 , -15.14814815, -14.51910287,
#        -13.90458302, -13.30442163, -12.71845173, -12.14650639,
#        -11.58841862, -11.04402148, -10.51314801,  -9.99563124,
#         -9.49130423,  -9.        ,  -8.5215516 ,  -8.05579208,
#         -7.60255447,  -7.16167181,  -6.73297715,  -6.31630353,
#         -5.91148399,  -5.51835156,  -5.13673929,  -4.76648023,
#         -4.40740741,  -4.05935387,  -3.72215266,  -3.39563681,
#         -3.07963937,  -2.77399338,  -2.47853188,  -2.1930879 ,
#         -1.9174945 ,  -1.65158472,  -1.39519159,  -1.14814815,
#         -0.91028745,  -0.68144252,  -0.46144642,  -0.25013218,
#         -0.04733283,   0.14711857,   0.33338899,   0.51164538,
#          0.68205471,   0.84478393,   1.        ,   1.14786988,
#          1.28856054,   1.42223892,   1.54907199,   1.6692267 ,
#          1.78287002,   1.89016891,   1.99129031,   2.0864012 ,
#          2.17566853,   2.25925926,   2.33734035,   2.41007875,
#          2.47764143,   2.54019534,   2.59790745,   2.65094471,
#          2.69947408,   2.74366252,   2.78367699,   2.81968445,
#          2.85185185,   2.88034616,   2.90533434,   2.92698333,
#          2.94546011,   2.96093163,   2.97356485,   2.98352673,
#          2.99098422,   2.99610429,   2.9990539 ,   3.        ])

# %%
print('Наименьшее значение: ', y(x)[np.argmin(y(x))])
# Out:
# Наименьшее значение:  -33.0

# %%
print('Наибольшее значение: ', y(x)[np.argmax(y(x))])
# Out:
# Наибольшее значение:  3.0

# %% [markdown]
# Пример линейной регрессии - это применение полиномов на практике. В следующем примере дан датасет x, y, сгенерированный рандомно. Мы можем использовать линейную регрессию, чтобы предсказать значение переменной y от x.

# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression

np.random.seed(0)
x = 2 - 3 * np.random.normal(0, 1, 200)
y = x - 2 * (x ** 2) + 0.5 * (x ** 3) + np.random.normal(-3, 3, 200)

# transforming the data to include another axis
x = x[:, np.newaxis]
y = y[:, np.newaxis]

model = LinearRegression()
model.fit(x, y)
y_pred = model.predict(x)

plt.scatter(x, y, s=10)
plt.scatter(x, y_pred, color='r', s=10)
plt.show()

# %%
from sklearn.preprocessing import PolynomialFeatures 
  
poly = PolynomialFeatures(degree = 2) 
X_poly = poly.fit_transform(x) 
  
poly.fit(X_poly, y) 
lin2 = LinearRegression()
model = lin2.fit(X_poly, y) 
y_pred = model.predict(poly.fit_transform(x))

plt.scatter(x, y, s=10)
plt.scatter(x, y_pred, marker='o', s=10)
plt.show()

# %%
from sklearn.preprocessing import PolynomialFeatures 
  
poly = PolynomialFeatures(degree = 3) 
X_poly = poly.fit_transform(x) 
  
poly.fit(X_poly, y) 
lin2 = LinearRegression()
model = lin2.fit(X_poly, y) 
y_pred = model.predict(poly.fit_transform(x))

plt.scatter(x, y, s=10)
plt.scatter(x, y_pred, marker='o', s=10)
plt.show()

# %% [markdown]
# ### В данном случае идеальный вариант это степень 3.

# %% [markdown]
# В данном примере найден полином первой степени. Как можно улучшить данную модель? Написать пример.
